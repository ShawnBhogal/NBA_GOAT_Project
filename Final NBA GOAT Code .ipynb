# %%
def intro():

    print ("Welcome!\n")
    print ("This your very own NBA Greatest of All Time (G.O.A.T) Calculator!")
    print ("Here you will be able to customize and create your customized statistical G.O.A.T")
    print ("\nInstructions:")
    print ("1) Input a number from 1 to 41 in order to choose statistical category.")
    print ("2) Input a weight from 1 to 10 indicating indicating importance for G.O.A.T calculation")
    print ("3) When finished enter 42 to calculate!") 
    
    print ("\nUNLESS SPECIFIED, ASSUME ALL CATEGORIES ARE PER GAME\n")
    print ("REGULAR STATS:")
    print (" 1. Total Career Games Played")  
    print (" 2. Total Career Minutes Played")
    print (" 3. Field Goals Made ")
    print (" 4. Field Goals Attempted")
    print (" 5. 2-Pointers Made")
    print (" 6. 2-Pointers Attempted")
    print (" 7. 3-Pointers Made")
    print (" 8. 3-Pointers Attempted")
    print (" 9. Free Throws Made")
    print ("10. Free Throws Attempted")
    print ("11. Offensive Rebounds")
    print ("12. Defensive Rebounds")
    print ("13. Total Rebounds")
    print ("14. Assists")
    print ("15. Steals")
    print ("16. Blocks")
    print ("17. Points")
    print ("18. Field Goal Percentage")
    print ("19. 2-Point Percentage")
    print ("20. 3-Point Percentage")
    print ("\nADVANCED STATS:")
    print ("21. " + "\033[1m" + "Effective Field Goal Percentage" + "\033[0m")
    print ("    - This statistic adjusts for the fact that a 3-point field goal is worth one more point than a 2-point field goal.")
    print ("22. " + "\033[1m" + "Free Throw Percentage" + "\033[0m")
    print ("23. " + "\033[1m" + "Trueshooting Percentage" + "\033[0m")
    print ("    - A measure of shooting efficiency that takes into account 2-point field goals, 3-point field goals, and free throws.")
    print ("24. " + "\033[1m" + " Player Efficiency Rating (PER)" + "\033[0m")
    print ("    - A measure of per-minute production standardized such that the league average is 15.")
    print ("25. " + "\033[1m" + " 3-Point Attempt Rate" + "\033[0m")
    print ("    - Percentage of FG Attempts from 3-Point Range")
    print ("26. " + "\033[1m" +  "Free Throw Attempt Rate" + "\033[0m")
    print ("    - Number of FT Attempts Per FG Attempt")
    print ("27. " + "\033[1m" +  "Offensive Rebound Percentage" + "\033[0m")
    print ("    - An estimate of the percentage of available offensive rebounds a player grabbed while on the floor.")
    print ("28. " + "\033[1m" +  "Defensive Rebound Percentage" + "\033[0m")
    print ("    - An estimate of the percentage of available defensive rebounds a player grabbed while on the floor.")
    print ("29. " + "\033[1m" +  "Total Rebound Percentage" + "\033[0m")
    print ("    - An estimate of the percentage of available rebounds a player grabbed while on the floor.")
    print ("30. " + "\033[1m" +  "Assist Percentage" + "\033[0m")
    print ("    - An estimate of the percentage of teammate field goals a player assisted while on the floor.")
    print ("31. " + "\033[1m" +  "Steal Percentage" + "\033[0m")
    print ("    - An estimate of the percentage of opponent possessions that end with a steal while on the floor.")
    print ("32. " + "\033[1m" + "Block Percentage" + "\033[0m")
    print ("    - An estimate of the percentage of opponent two-point field goal attempts blocked by while on the floor.")  
    print ("33. " + "\033[1m" + "Offensive Rating" + "\033[0m")
    print ("    - An estimate of points produced (players) or scored (teams) per 100 possessions")
    print ("34. " + "\033[1m" + "Defensive Rating" + "\033[0m")
    print ("    - An estimate of points allowed per 100 possessions")
    print ("35. " + "\033[1m" + "Offensive Win Shares" + "\033[0m")
    print ("    - An estimate of the number of wins contributed by a player due to his offense.") 
    print ("36. " + "\033[1m" + "Defensive Win Shares" + "\033[0m")
    print ("    - An estimate of the number of wins contributed by a player due to his defense.")
    print ("37. " + "\033[1m" + "Win Shares Per 48 Minutes" + "\033[0m")
    print ("    - An estimate of the number of wins contributed by a player per 48 minutes (league average is approximately .100)")
    print ("38. " + "\033[1m" + "Offensive Box Plus/Minus" + "\033[0m")
    print ("    - A box score estimate of the offensive points per 100 possessions a player contributed above a league-average player.")
    print ("39. " + "\033[1m" + "Defensive Box Plus/Minus" + "\033[0m")
    print ("    - A box score estimate of the defensive points per 100 possessions a player contributed above a league-average player.") 
    print ("40. " + "\033[1m" + "Box Plus/Minus" + "\033[0m")
    print ("    - A box score estimate of the points per 100 possessions a player contributed above a league-average player.")
    print ("41. " + "\033[1m" + "Value Over Replacement Player (VORP)" + "\033[0m")
    print ("    - An estimate of the points per 100 possessions that a player contributed above a replacement-level (-2.0) player")
    print ("42. " + "\033[1m" + "CALCULATE!" + "\033[0m")

# %%
# this is where the user will choose which stats they want to evaluate 
# user will also be prompted to input a number from 1 to 10 as weight for the importance of each stat

cat_dict = {
     1 : "games_played", 
     2 : "mp",
     3 : "fg" ,
     4 : "fga", 
     5 : "two_p", 
     6 : "two_pa",
     7 : "three_p", 
     8 : "three_pa",
     9 : "ft", 
    10 : "fta",
    11 : "orb", 
    12 : "drb", 
    13 : "trb", 
    14 : "ast", 
    15 : "stl",
    16 : "blk", 
    17 : "pts", 
    18 : "fg_pct", 
    19 : "two_p_pct", 
    20 : "three_p_pct", 
    21 : "efg_pct", 
    22 : "ft_pct", 
    23 : "trueshooting_pct", 
    24 : "per", 
    25 : "three_par",
    26 : "ftr", 
    27 : "orb_pct", 
    28 : "drb_pct", 
    29 : "trb_pct", 
    30 : "ast_pct", 
    31 : "stl_pct", 
    32 : "blk_pct", 
    33 : "ortg", 
    34 : "drtg", 
    35 : "ows", 
    36 : "dws", 
    37 : "ws", 
    38 : "obpm", 
    39 : "dbpm",  
    40 : "bpm", 
    41 : "vorp" 
}

# dictionary for storing values from 1-10 that user inputs for each category weight
weight_dict = {
}

# %%
def user_input():
    

    #user number input to select category
    cat_num = ""
    cat_weight = ""

    while cat_num != 42:
        try:
            cat_num = int(input("\nEnter a number from 1 to 41 to select statistical category: "))
            if cat_num < 0 or cat_num > 42:
                raise ValueError 
            elif cat_num == 42:
                print ("\nCalculations Complete!\n")
                break
        except ValueError:
            print("\nThis is not a valid input. \nTry again!") 
        else:
            while True:
                try:
                    # prompt user with the category that they selected
                    cat_weight = int(input((cat_dict[cat_num] + ": ")))
                    if cat_weight < 0 or cat_weight > 10:
                        raise ValueError
                except ValueError:
                    print("\nThis is not a valid input. \nTry again!")
                else:
                    # insert cat_weight in 2nd dictionary
                    weight_dict[cat_dict[cat_num]] =  cat_weight
                    print(weight_dict)
                    break

# %%
# method for extracting weight dict values into list
def calculation():
    values_weight_dict = list(weight_dict.values())

    list_size = len(values_weight_dict)

    #sql query to import stats from category user chooses

    import psycopg2 as pg2

    conn = pg2.connect(database = 'NBA GOAT Project', user = 'postgres', password = 'thebeatles')

    cur = conn.cursor()

    cur.execute('SELECT {} FROM all_stats'.format(", ".join(weight_dict)))

    from decimal import Decimal

    players = cur.fetchall()

    cur.close()

    #sql query to import names of players

    import psycopg2 as pg2

    conn = pg2.connect(database = 'NBA GOAT Project', user = 'postgres', password = 'thebeatles')

    cur = conn.cursor()

    cur.execute('''SELECT player FROM all_stats''')

    player_names = [r[0] for r in cur.fetchall()]

    cur.close()
    

    # finding min max

    #inputting zeros into empty arrays for how many categories user inputs
    min_val_array = []
    max_val_array = []
    index_val = 0
    while (index_val < list_size):
        min_val_array.append(1000000000)
        max_val_array.append(0)
        index_val += 1


    #inputting min and max values into zeroed arrays
    for person in players:
        index = 0
        while (index < list_size):
            if (person[index] != None):
                if (person[index] < min_val_array[index]):
                    min_val_array[index] = person[index]
                if (person[index] > max_val_array[index]):
                    max_val_array[index] = person[index]
            index += 1

    calculated_values = {}

    count = 0
    for person in players:
        index_3 = 0 
        calculated_player = []
        while (index_3 < list_size):
            if (person[index_3] != None):
                # (x - min)/(max - min)
                calced_result = (person[index_3] - min_val_array[index_3])/(max_val_array[index_3] - min_val_array[index_3])
                calced_result = round(calced_result, 3) 
                calculated_player.append(calced_result)
            else:
                calculated_player.append(None)
            index_3 += 1

    #summing up calculated weights                            
        sum_calculated_player = 0 
        for num in calculated_player:
            if (num != None):
                sum_calculated_player += num

    #assigning name to each calculated weight
        calculated_values[player_names[count]] = sum_calculated_player

        count += 1

    sorted_values = sorted(calculated_values.items(), key=lambda x: x[1], reverse=True) 



    rank = 1
    for val in sorted_values:
        print(str(rank) + ". " + str(val[0]) + ":      " + str(val[1]))
        rank += 1

# %%
intro()
user_input() 
calculation()
# Out:
# Welcome!
#
# This your very own NBA Greatest of All Time (G.O.A.T) Calculator!
# Here you will be able to customize and create your customized statistical G.O.A.T
#
# Instructions:
# 1) Input a number from 1 to 41 in order to choose statistical category.
# 2) Input a weight from 1 to 10 indicating indicating importance for G.O.A.T calculation
# 3) When finished enter 42 to calculate!
#
# UNLESS SPECIFIED, ASSUME ALL CATEGORIES ARE PER GAME
#
# REGULAR STATS:
#  1. Total Career Games Played
#  2. Total Career Minutes Played
#  3. Field Goals Made
#  4. Field Goals Attempted
#  5. 2-Pointers Made
#  6. 2-Pointers Attempted
#  7. 3-Pointers Made
#  8. 3-Pointers Attempted
#  9. Free Throws Made
# 10. Free Throws Attempted
# 11. Offensive Rebounds
# 12. Defensive Rebounds
# 13. Total Rebounds
# 14. Assists
# 15. Steals
# 16. Blocks
# 17. Points
# 18. Field Goal Percentage
# 19. 2-Point Percentage
# 20. 3-Point Percentage
#
# ADVANCED STATS:
# 21. Effective Field Goal Percentage
#     - This statistic adjusts for the fact that a 3-point field goal is worth one more point than a 2-point field goal.
# 22. Free Throw Percentage
# 23. Trueshooting Percentage
#     - A measure of shooting efficiency that takes into account 2-point field goals, 3-point field goals, and free throws.
# 24.  Player Efficiency Rating (PER)
#     - A measure of per-minute production standardized such that the league average is 15.
# 25.  3-Point Attempt Rate
#     - Percentage of FG Attempts from 3-Point Range
# 26. Free Throw Attempt Rate
#     - Number of FT Attempts Per FG Attempt
# 27. Offensive Rebound Percentage
#     - An estimate of the percentage of available offensive rebounds a player grabbed while on the floor.
# 28. Defensive Rebound Percentage
#     - An estimate of the percentage of available defensive rebounds a player grabbed while on the floor.
# 29. Total Rebound Percentage
#     - An estimate of the percentage of available rebounds a player grabbed while on the floor.
# 30. Assist Percentage
#     - An estimate of the percentage of teammate field goals a player assisted while on the floor.
# 31. Steal Percentage
#     - An estimate of the percentage of opponent possessions that end with a steal while on the floor.
# 32. Block Percentage
#     - An estimate of the percentage of opponent two-point field goal attempts blocked by while on the floor.
# 33. Offensive Rating
#     - An estimate of points produced (players) or scored (teams) per 100 possessions
# 34. Defensive Rating
#     - An estimate of points allowed per 100 possessions
# 35. Offensive Win Shares
#     - An estimate of the number of wins contributed by a player due to his offense.
# 36. Defensive Win Shares
#     - An estimate of the number of wins contributed by a player due to his defense.
# 37. Win Shares Per 48 Minutes
#     - An estimate of the number of wins contributed by a player per 48 minutes (league average is approximately .100)
# 38. Offensive Box Plus/Minus
#     - A box score estimate of the offensive points per 100 possessions a player contributed above a league-average player.
# 39. Defensive Box Plus/Minus
#     - A box score estimate of the defensive points per 100 possessions a player contributed above a league-average player.
# 40. Box Plus/Minus
#     - A box score estimate of the points per 100 possessions a player contributed above a league-average player.
# 41. Value Over Replacement Player (VORP)
#     - An estimate of the points per 100 possessions that a player contributed above a replacement-level (-2.0) player
# 42. CALCULATE!
#
# Enter a number from 1 to 41 to select statistical category: 33
# ortg: 10
# {'ortg': 10}
#
# Enter a number from 1 to 41 to select statistical category: 19
# two_p_pct: daddy
#
# This is not a valid input.
# Try again!
# two_p_pct: 5
# {'ortg': 10, 'two_p_pct': 5}
#
# Enter a number from 1 to 41 to select statistical category: 17
# pts: 8
# {'ortg': 10, 'two_p_pct': 5, 'pts': 8}
#
# Enter a number from 1 to 41 to select statistical category: 3
# fg: 9
# {'ortg': 10, 'two_p_pct': 5, 'pts': 8, 'fg': 9}
#
# Enter a number from 1 to 41 to select statistical category: 30
# ast_pct: 10
# {'ortg': 10, 'two_p_pct': 5, 'pts': 8, 'fg': 9, 'ast_pct': 10}
#
# Enter a number from 1 to 41 to select statistical category: 42
#
# Calculations Complete!
#
# 1. LeBron James:      3.806
# 2. Michael Jordan:      3.748
# 3. Magic Johnson:      3.462
# 4. Chris Paul:      3.436
# 5. Kevin Durant:      3.368
# 6. Stephen Curry:      3.364
# 7. James Harden:      3.351
# 8. Kareem Abdul-Jabbar:      3.299
# 9. Larry Bird:      3.290
# 10. Karl-Anthony Towns:      3.244
# 11. Charles Barkley:      3.229
# 12. John Stockton:      3.223
# 13. Damian Lillard:      3.211
# 14. Russell Westbrook:      3.210
# 15. Shaquille O'Neal:      3.196
# 16. Nikola Jokic:      3.188
# 17. Kyrie Irving:      3.167
# 18. Adrian Dantley:      3.159
# 19. Karl Malone:      3.109
# 20. George Gervin:      3.107
# 21. Kevin Johnson:      3.097
# 22. Anthony Davis:      3.067
# 23. Giannis Antetokounmpo:      3.031
# 24. Kobe Bryant:      3.002
# 25. Dwyane Wade:      3.002
# 26. Allen Iverson:      2.989
# 27. Steve Nash:      2.984
# 28. Blake Griffin:      2.971
# 29. Clyde Drexler:      2.929
# 30. Wilt Chamberlain:      2.897
# 31. Julius Erving:      2.880
# 32. Alex English:      2.860
# 33. Dominique Wilkins:      2.849
# 34. Bernard King:      2.843
# 35. Mark Price:      2.828
# 36. Marques Johnson:      2.822
# 37. Kiki Vandeweghe:      2.814
# 38. Deron Williams:      2.803
# 39. Isiah Thomas:      2.801
# 40. David Robinson:      2.790
# 41. David Thompson:      2.787
# 42. Stephon Marbury:      2.777
# 43. John Wall:      2.775
# 44. Devin Booker:      2.762
# 45. Kawhi Leonard:      2.761
# 46. Brandon Roy:      2.751
# 47. Gary Payton:      2.740
# 48. Artis Gilmore:      2.729
# 49. Dan Issel:      2.721
# 50. Brad Daugherty:      2.720
# 51. Chris Mullin:      2.720
# 52. Walter Davis:      2.719
# 53. Isaiah Thomas:      2.713
# 54. Kevin McHale:      2.707
# 55. Bob Lanier:      2.703
# 56. Reggie Miller:      2.701
# 57. Derrick Rose:      2.701
# 58. Dirk Nowitzki:      2.689
# 59. Hakeem Olajuwon:      2.689
# 60. Rick Barry:      2.674
# 61. Carmelo Anthony:      2.672
# 62. Bradley Beal:      2.668
# 63. Tiny Archibald:      2.664
# 64. Tony Parker:      2.664
# 65. Larry Nance:      2.663
# 66. Rudy Gobert:      2.649
# 67. Reggie Theus:      2.646
# 68. Kemba Walker:      2.642
# 69. Chris Webber:      2.638
# 70. Gilbert Arenas:      2.631
# 71. Mark Aguirre:      2.626
# 72. James Worthy:      2.618
# 73. Tracy McGrady:      2.609
# 74. Jeff Hornacek:      2.608
# 75. Jerry West:      2.605
# 76. Oscar Robertson:      2.603
# 77. Sam Cassell:      2.599
# 78. Tim Duncan:      2.597
# 79. Jimmy Butler:      2.582
# 80. Kevin Garnett:      2.580
# 81. Mitch Richmond:      2.579
# 82. Norm Nixon:      2.566
# 83. Ray Allen:      2.557
# 84. LaMarcus Aldridge:      2.554
# 85. Sidney Moncrief:      2.554
# 86. Calvin Murphy:      2.545
# 87. World B. Free:      2.544
# 88. DeMar DeRozan:      2.542
# 89. Rolando Blackman:      2.538
# 90. Paul Westphal:      2.538
# 91. Pau Gasol:      2.536
# 92. Amar'e Stoudemire:      2.532
# 93. Maurice Cheeks:      2.531
# 94. Tim Hardaway:      2.531
# 95. Pete Maravich:      2.531
# 96. Bob McAdoo:      2.531
# 97. Jeff Ruland:      2.530
# 98. Yao Ming:      2.521
# 99. Al Horford:      2.519
# 100. Walt Frazier:      2.514
# 101. Kyle Lowry:      2.508
# 102. Calvin Natt:      2.504
# 103. Otis Birdsong:      2.503
# 104. Chris Bosh:      2.503
# 105. Patrick Ewing:      2.493
# 106. Jrue Holiday:      2.488
# 107. Gus Williams:      2.488
# 108. CJ McCollum:      2.483
# 109. Terrell Brandon:      2.480
# 110. Baron Davis:      2.477
# 111. Dwight Howard:      2.477
# 112. Scottie Pippen:      2.472
# 113. Grant Hill:      2.469
# 114. DeAndre Jordan:      2.469
# 115. Moses Malone:      2.468
# 116. Paul Pierce:      2.468
# 117. Ty Lawson:      2.464
# 118. DeMarcus Cousins:      2.450
# 119. Lou Hudson:      2.447
# 120. Eddie Johnson:      2.441
# 121. Mike Conley:      2.439
# 122. Mike Mitchell:      2.437
# 123. Paul George:      2.435
# 124. Joe Dumars:      2.432
# 125. Jeff Malone:      2.430
# 126. Kevin Love:      2.429
# 127. Chauncey Billups:      2.427
# 128. Reggie Lewis:      2.427
# 129. Andrew Toney:      2.426
# 130. Steve Francis:      2.424
# 131. Michael Redd:      2.422
# 132. Rod Strickland:      2.417
# 133. Terry Porter:      2.414
# 134. Klay Thompson:      2.414
# 135. Jose Calderon:      2.409
# 136. Earl Monroe:      2.407
# 137. Jamaal Wilkes:      2.407
# 138. Kenny Smith:      2.397
# 139. Andre Miller:      2.393
# 140. Nikola Vucevic:      2.392
# 141. Doug Collins:      2.389
# 142. Larry Johnson:      2.389
# 143. Derek Harper:      2.388
# 144. Eric Bledsoe:      2.380
# 145. Michael Adams:      2.379
# 146. Brad Davis:      2.376
# 147. Glenn Robinson:      2.370
# 148. Detlef Schrempf:      2.365
# 149. Hassan Whiteside:      2.365
# 150. Carlos Boozer:      2.362
# 151. John Havlicek:      2.360
# 152. Ricky Pierce:      2.360
# 153. Anfernee Hardaway:      2.356
# 154. Monta Ellis:      2.350
# 155. Jim Paxson:      2.346
# 156. Glen Rice:      2.343
# 157. Dave Bing:      2.341
# 158. David Lee:      2.337
# 159. Rudy Tomjanovich:      2.334
# 160. Gail Goodrich:      2.333
# 161. Darren Collison:      2.329
# 162. Micheal Williams:      2.328
# 163. John Drew:      2.323
# 164. Khris Middleton:      2.318
# 165. Elgin Baylor:      2.316
# 166. Bob Dandridge:      2.313
# 167. Jonas Valanciunas:      2.312
# 168. Julius Randle:      2.310
# 169. Brook Lopez:      2.308
# 170. Jeff Teague:      2.306
# 171. Gordon Hayward:      2.304
# 172. Purvis Short:      2.302
# 173. Mark Jackson:      2.301
# 174. Zach LaVine:      2.300
# 175. Manu Ginobili:      2.297
# 176. Orlando Woolridge:      2.297
# 177. Otis Thorpe:      2.294
# 178. Nick Van Exel:      2.294
# 179. Mike Bibby:      2.293
# 180. Dale Ellis:      2.293
# 181. Brian Winters:      2.289
# 182. Shareef Abdur-Rahim:      2.285
# 183. Sherman Douglas:      2.285
# 184. Randy Smith:      2.281
# 185. Brian Taylor:      2.280
# 186. Tobias Harris:      2.277
# 187. Kelly Tripucka:      2.276
# 188. Kevin Porter:      2.268
# 189. Rajon Rondo:      2.268
# 190. Marc Gasol:      2.267
# 191. Fat Lever:      2.267
# 192. Antawn Jamison:      2.266
# 193. Peja Stojakovic:      2.266
# 194. Tyreke Evans:      2.264
# 195. Cedric Maxwell:      2.264
# 196. Billy Knight:      2.262
# 197. Elton Brand:      2.255
# 198. Ray Williams:      2.254
# 199. Vince Carter:      2.253
# 200. Alvin Robertson:      2.250
# 201. Vern Fleming:      2.249
# 202. Richard Hamilton:      2.249
# 203. Micheal Ray Richardson:      2.248
# 204. Dave Cowens:      2.247
# 205. Joe Johnson:      2.246
# 206. Gene Banks:      2.245
# 207. Bobby Jones:      2.242
# 208. Victor Oladipo:      2.242
# 209. Danilo Gallinari:      2.241
# 210. Hersey Hawkins:      2.241
# 211. Fred Brown:      2.240
# 212. Jason Kidd:      2.240
# 213. Danny Ainge:      2.239
# 214. Steven Adams:      2.237
# 215. Kevin Martin:      2.235
# 216. Jamal Mashburn:      2.230
# 217. Byron Scott:      2.226
# 218. Wally Szczerbiak:      2.226
# 219. Andrew Wiggins:      2.225
# 220. Steve Smith:      2.222
# 221. Robert Parish:      2.221
# 222. Shawn Marion:      2.220
# 223. Alonzo Mourning:      2.220
# 224. Tom Chambers:      2.219
# 225. Alvan Adams:      2.213
# 226. Kyle Macy:      2.211
# 227. Mookie Blaylock:      2.210
# 228. Andre Drummond:      2.210
# 229. Jason Terry:      2.210
# 230. Terry Cummings:      2.206
# 231. Johnny Moore:      2.206
# 232. Jason Richardson:      2.206
# 233. Reggie Jackson:      2.202
# 234. Muggsy Bogues:      2.199
# 235. Al Jefferson:      2.199
# 236. Kenny Anderson:      2.197
# 237. Lou Williams:      2.196
# 238. Mahmoud Abdul-Rauf:      2.194
# 239. Pooh Richardson:      2.192
# 240. Dennis Schroder:      2.192
# 241. Paul Millsap:      2.188
# 242. Andre Iguodala:      2.186
# 243. Jay Humphries:      2.183
# 244. Larry Kenon:      2.179
# 245. John Lucas:      2.175
# 246. Sleepy Floyd:      2.174
# 247. Latrell Sprewell:      2.174
# 248. Scott Skiles:      2.173
# 249. Dana Barros:      2.166
# 250. Jordan Clarkson:      2.163
# 251. Doc Rivers:      2.163
# 252. Elvin Hayes:      2.159
# 253. Mo Williams:      2.159
# 254. Greg Monroe:      2.153
# 255. Bill Laimbeer:      2.151
# 256. Eric Gordon:      2.149
# 257. Kenneth Faried:      2.144
# 258. Zach Randolph:      2.144
# 259. Elfrid Payton:      2.143
# 260. Cedric Ceballos:      2.141
# 261. Michael Finley:      2.141
# 262. Andrew Bynum:      2.138
# 263. George Hill:      2.137
# 264. Jameer Nelson:      2.137
# 265. Brent Barry:      2.134
# 266. Rudy Gay:      2.134
# 267. Rodney McCray:      2.134
# 268. Spud Webb:      2.134
# 269. Eddie Jones:      2.133
# 270. Chandler Parsons:      2.132
# 271. Jack Sikma:      2.130
# 272. Arvydas Sabonis:      2.129
# 273. Mason Plumlee:      2.128
# 274. Danny Manning:      2.127
# 275. Damon Stoudamire:      2.127
# 276. Sedale Threatt:      2.127
# 277. Horace Grant:      2.125
# 278. Avery Johnson:      2.121
# 279. Xavier McDaniel:      2.121
# 280. Mike Newlin:      2.120
# 281. John Paxson:      2.120
# 282. Enes Kanter:      2.119
# 283. J.J. Redick:      2.119
# 284. Bob Pettit:      2.115
# 285. David West:      2.115
# 286. Phil Smith:      2.114
# 287. Johnny Dawkins:      2.113
# 288. Rashard Lewis:      2.111
# 289. Geoff Petrie:      2.111
# 290. Paul Pressey:      2.099
# 291. Rik Smits:      2.098
# 292. Wayman Tisdale:      2.098
# 293. B.J. Armstrong:      2.097
# 294. Allan Houston:      2.097
# 295. Buck Williams:      2.096
# 296. Corey Maggette:      2.094
# 297. Anthony Mason:      2.089
# 298. Eric Murdock:      2.089
# 299. Isaiah Rider:      2.089
# 300. Lamar Odom:      2.088
# 301. Serge Ibaka:      2.086
# 302. Bill Walton:      2.084
# 303. Otto Porter:      2.076
# 304. Larry Drew:      2.073
# 305. Danny Granger:      2.073
# 306. Evan Fournier:      2.071
# 307. Dennis Johnson:      2.070
# 308. Rickey Green:      2.067
# 309. Brad Miller:      2.066
# 310. Chuck Person:      2.065
# 311. Sean Elliott:      2.064
# 312. Josh Childress:      2.062
# 313. Bill Cartwright:      2.061
# 314. Nene Hilario:      2.056
# 315. Nicolas Batum:      2.054
# 316. Phil Ford:      2.054
# 317. Tyson Chandler:      2.053
# 318. Rasheed Wallace:      2.053
# 319. Spencer Haywood:      2.051
# 320. Kelvin Ransey:      2.050
# 321. Swen Nater:      2.048
# 322. Wes Unseld:      2.048
# 323. Devin Harris:      2.046
# 324. Nick Anderson:      2.043
# 325. Joe Barry Carroll:      2.043
# 326. Kerry Kittles:      2.043
# 327. Thaddeus Young:      2.043
# 328. Jalen Rose:      2.042
# 329. Andrei Kirilenko:      2.041
# 330. Brandon Jennings:      2.039
# 331. Derrick Favors:      2.038
# 332. Derrick Coleman:      2.036
# 333. Dan Roundfield:      2.036
# 334. Junior Bridgeman:      2.032
# 335. Jerry Stackhouse:      2.032
# 336. Ricky Rubio:      2.028
# 337. Amir Johnson:      2.025
# 338. Luol Deng:      2.023
# 339. Jay Vincent:      2.016
# 340. Carl Landry:      2.014
# 341. Darryl Dawkins:      2.013
# 342. Vlade Divac:      2.013
# 343. Kevin Gamble:      2.013
# 344. T.J. Ford:      2.012
# 345. Jeremy Lin:      2.012
# 346. Campy Russell:      2.012
# 347. Ron Harper:      2.010
# 348. Mehmet Okur:      2.010
# 349. Antoine Walker:      2.010
# 350. Johnny Davis:      2.008
# 351. Mychal Thompson:      2.006
# 352. Mario Elie:      2.004
# 353. Jo Jo White:      2.001
# 354. Cliff Robinson:      2.000
# 355. Gary Harris:      1.999
# 356. Kelly Olynyk:      1.997
# 357. Charlie Scott:      1.994
# 358. Vinnie Johnson:      1.993
# 359. Marcin Gortat:      1.992
# 360. Darrell Griffith:      1.991
# 361. Jamal Crawford:      1.986
# 362. Steve Johnson:      1.985
# 363. Jason Williams:      1.985
# 364. Willie Anderson:      1.984
# 365. Dan Majerle:      1.984
# 366. Aaron Gordon:      1.979
# 367. Christian Laettner:      1.979
# 368. Vin Baker:      1.973
# 369. Cuttino Mobley:      1.973
# 370. Mike Woodson:      1.969
# 371. Jarrett Jack:      1.962
# 372. Richard Jefferson:      1.955
# 373. George McGinnis:      1.954
# 374. Geoff Huston:      1.951
# 375. Tom Owens:      1.951
# 376. Vinny Del Negro:      1.947
# 377. Scott Wedman:      1.947
# 378. David Wesley:      1.947
# 379. Draymond Green:      1.946
# 380. Ken Norman:      1.946
# 381. Austin Carr:      1.945
# 382. Ben Gordon:      1.943
# 383. Allen Leavell:      1.943
# 384. Mike Miller:      1.942
# 385. Dee Brown:      1.940
# 386. Shawn Kemp:      1.939
# 387. Nate Robinson:      1.938
# 388. Sam Perkins:      1.937
# 389. Keith Van Horn:      1.937
# 390. Joe Ingles:      1.936
# 391. Steve Stipanovich:      1.936
# 392. Rex Chapman:      1.935
# 393. Antonio Daniels:      1.932
# 394. Josh Smith:      1.932
# 395. Ricky Sobers:      1.932
# 396. Ramon Sessions:      1.930
# 397. Josh Howard:      1.927
# 398. Walt Bellamy:      1.926
# 399. Michael Cooper:      1.926
# 400. Cazzie Russell:      1.922
# 401. Ricky Davis:      1.919
# 402. Steve Mix:      1.919
# 403. J.J. Barea:      1.918
# 404. Charles Smith:      1.918
# 405. Luke Ridnour:      1.917
# 406. D.J. Augustin:      1.914
# 407. Billy Cunningham:      1.912
# 408. Ralph Sampson:      1.910
# 409. Maurice Lucas:      1.909
# 410. Derrick McKey:      1.908
# 411. Eric Money:      1.908
# 412. Raymond Felton:      1.907
# 413. Brandon Knight:      1.907
# 414. Roy Hinson:      1.905
# 415. Beno Udrih:      1.904
# 416. Ed Davis:      1.903
# 417. John Starks:      1.903
# 418. Boris Diaw:      1.900
# 419. Steve Kerr:      1.899
# 420. Armen Gilliam:      1.898
# 421. Gerald Henderson:      1.897
# 422. Ruben Patterson:      1.897
# 423. Jim McMillian:      1.896
# 424. Darrell Armstrong:      1.895
# 425. Greg Ballard:      1.888
# 426. Andrew Bogut:      1.885
# 427. Rodney Stuckey:      1.884
# 428. Wesley Matthews:      1.883
# 429. Gerald Wilkins:      1.878
# 430. Wesley Person:      1.877
# 431. Harrison Barnes:      1.875
# 432. James Donaldson:      1.874
# 433. Leandro Barbosa:      1.873
# 434. Jerry Sichting:      1.873
# 435. Luis Scola:      1.870
# 436. Joakim Noah:      1.864
# 437. Rory Sparrow:      1.863
# 438. Tristan Thompson:      1.863
# 439. Quintin Dailey:      1.862
# 440. Ryan Anderson:      1.861
# 441. Jeff McInnis:      1.858
# 442. Phil Chenier:      1.856
# 443. JaVale McGee:      1.855
# 444. Gerald Wallace:      1.854
# 445. Delonte West:      1.854
# 446. Stephen Jackson:      1.853
# 447. O.J. Mayo:      1.849
# 448. Sidney Wicks:      1.849
# 449. John Long:      1.848
# 450. Caron Butler:      1.845
# 451. Hal Greer:      1.842
# 452. Truck Robinson:      1.842
# 453. A.C. Green:      1.837
# 454. Wilson Chandler:      1.836
# 455. Derek Anderson:      1.834
# 456. Will Barton:      1.833
# 457. Robin Lopez:      1.833
# 458. Dell Curry:      1.830
# 459. James Edwards:      1.830
# 460. Billy Owens:      1.830
# 461. Matt Harpring:      1.829
# 462. Jeremy Lamb:      1.829
# 463. Bob Cousy:      1.828
# 464. Kermit Washington:      1.828
# 465. Earl Boykins:      1.827
# 466. Mike Dunleavy:      1.826
# 467. Kirk Hinrich:      1.826
# 468. Mickey Johnson:      1.826
# 469. Jim Jackson:      1.825
# 470. Patrick Beverley:      1.823
# 471. Frank Brickowski:      1.823
# 472. Eddy Curry:      1.819
# 473. Kendall Gill:      1.819
# 474. Antonio McDyess:      1.819
# 475. Clifford Robinson:      1.819
# 476. Nate McMillan:      1.816
# 477. Archie Clark:      1.811
# 478. Rod Higgins:      1.811
# 479. Hot Rod Williams:      1.810
# 480. Juwan Howard:      1.809
# 481. Zydrunas Ilgauskas:      1.806
# 482. Tayshaun Prince:      1.805
# 483. Taj Gibson:      1.802
# 484. Dennis Rodman:      1.799
# 485. Rony Seikaly:      1.799
# 486. Reggie Williams:      1.799
# 487. Bison Dele:      1.794
# 488. Tyronn Lue:      1.792
# 489. J.R. Smith:      1.790
# 490. Patty Mills:      1.788
# 491. Raef LaFrentz:      1.785
# 492. Hedo Turkoglu:      1.784
# 493. Butch Beard:      1.783
# 494. Tom Gugliotta:      1.781
# 495. Emeka Okafor:      1.779
# 496. Chucky Atkins:      1.777
# 497. Ronnie Brewer:      1.775
# 498. John Bagley:      1.774
# 499. Sonny Parker:      1.773
# 500. Marcus Thornton:      1.772
# 501. Rick Fox:      1.771
# 502. Robert Pack:      1.771
# 503. Lucius Allen:      1.768
# 504. Brevin Knight:      1.768
# 505. Dennis Scott:      1.768
# 506. Craig Hodges:      1.767
# 507. Lonnie Shelton:      1.767
# 508. Ed Pinckney:      1.766
# 509. Randy Wittman:      1.766
# 510. Dale Davis:      1.765
# 511. Jeff Green:      1.763
# 512. Norm Van Lier:      1.763
# 513. Lenny Wilkens:      1.762
# 514. Gorgui Dieng:      1.760
# 515. Elmore Smith:      1.759
# 516. Jared Dudley:      1.758
# 517. Bob Gross:      1.757
# 518. Gary Grant:      1.756
# 519. Arron Afflalo:      1.754
# 520. Jerry Lucas:      1.753
# 521. Vernon Maxwell:      1.750
# 522. Terry Catledge:      1.749
# 523. Johnny Newman:      1.747
# 524. Mike James:      1.746
# 525. Andrea Bargnani:      1.744
# 526. Al Harrington:      1.744
# 527. Tim McCormick:      1.744
# 528. Dick Snyder:      1.742
# 529. Shane Battier:      1.738
# 530. Kenyon Martin:      1.738
# 531. Robert Reid:      1.737
# 532. Doug Christie:      1.735
# 533. Dikembe Mutombo:      1.735
# 534. Trent Tucker:      1.735
# 535. Larry Hughes:      1.734
# 536. Mark Olberding:      1.731
# 537. Kenny Carr:      1.730
# 538. Mike Gminski:      1.728
# 539. Bobby Phills:      1.728
# 540. Thurl Bailey:      1.727
# 541. Marcus Morris:      1.727
# 542. Darnell Valentine:      1.727
# 543. John Battle:      1.726
# 544. Kentavious Caldwell-Pope:      1.725
# 545. John Mengelt:      1.725
# 546. Jae Crowder:      1.722
# 547. Blue Edwards:      1.722
# 548. James Johnson:      1.722
# 549. Kevin Willis:      1.722
# 550. Ron Anderson:      1.720
# 551. Nick Collison:      1.720
# 552. Jeff Mullins:      1.720
# 553. Sam Jones:      1.718
# 554. Bonzi Wells:      1.718
# 555. Troy Murphy:      1.717
# 556. Anderson Varejao:      1.714
# 557. Ersan ?lyasova:      1.713
# 558. Loy Vaught:      1.712
# 559. Kyle Korver:      1.710
# 560. Ron Boone:      1.708
# 561. Lionel Simmons:      1.708
# 562. Ish Smith:      1.707
# 563. Metta World Peace:      1.707
# 564. Jermaine O'Neal:      1.706
# 565. Jamaal Tinsley:      1.706
# 566. Doug West:      1.706
# 567. Bo Outlaw:      1.705
# 568. Marvin Williams:      1.704
# 569. Willis Reed:      1.703
# 570. Chris Wilcox:      1.701
# 571. Trevor Ariza:      1.700
# 572. John Williams:      1.700
# 573. Matt Bonner:      1.699
# 574. Aaron Brooks:      1.697
# 575. Clarence Weatherspoon:      1.697
# 576. Jerami Grant:      1.694
# 577. Mike Bantom:      1.691
# 578. Winston Garland:      1.690
# 579. Chris Morris:      1.689
# 580. Alvin Williams:      1.689
# 581. Antoine Carr:      1.688
# 582. Michael Cage:      1.687
# 583. Bimbo Coles:      1.687
# 584. Jack Twyman:      1.687
# 585. Lionel Hollins:      1.686
# 586. Bingo Smith:      1.684
# 587. Travis Best:      1.683
# 588. Darwin Cook:      1.683
# 589. Lloyd Neal:      1.683
# 590. Greg Anthony:      1.682
# 591. Craig Ehlo:      1.682
# 592. Anthony Parker:      1.682
# 593. LaPhonso Ellis:      1.680
# 594. Courtney Lee:      1.680
# 595. Mario Chalmers:      1.679
# 596. Bailey Howell:      1.679
# 597. Anthony Morrow:      1.679
# 598. Ron Brewer:      1.678
# 599. Jerome Kersey:      1.678
# 600. Terry Mills:      1.678
# 601. Bryant Reeves:      1.676
# 602. Walt Williams:      1.675
# 603. Cliff Hagan:      1.674
# 604. Voshon Lenard:      1.674
# 605. Rodney Rogers:      1.673
# 606. Michael Beasley:      1.672
# 607. Lester Conner:      1.671
# 608. Reggie King:      1.671
# 609. Robert Covington:      1.670
# 610. Carlos Arroyo:      1.669
# 611. Albert King:      1.669
# 612. John Johnson:      1.668
# 613. Chris Gatling:      1.667
# 614. Cliff Levingston:      1.667
# 615. Don Buse:      1.666
# 616. Matt Barnes:      1.665
# 617. Pervis Ellison:      1.665
# 618. Richie Guerin:      1.664
# 619. Chris Mills:      1.664
# 620. Markieff Morris:      1.663
# 621. Bob Sura:      1.663
# 622. Trevor Booker:      1.661
# 623. Mikki Moore:      1.661
# 624. Corliss Williamson:      1.660
# 625. Dave Greenwood:      1.659
# 626. Jimmy Walker:      1.659
# 627. Frank Johnson:      1.658
# 628. Brandon Bass:      1.656
# 629. Harvey Grant:      1.656
# 630. Tom Henderson:      1.656
# 631. Phil Hubbard:      1.656
# 632. Shaun Livingston:      1.656
# 633. Oliver Miller:      1.655
# 634. Rafer Alston:      1.652
# 635. Connie Hawkins:      1.650
# 636. Jim McElroy:      1.650
# 637. Brian Grant:      1.648
# 638. Dion Waiters:      1.646
# 639. Tony Campbell:      1.644
# 640. Chet Walker:      1.644
# 641. Jim Cleamons:      1.642
# 642. Allan Bristow:      1.639
# 643. Cory Joseph:      1.636
# 644. Terry Teagle:      1.636
# 645. Jon Barry:      1.635
# 646. Donyell Marshall:      1.631
# 647. Tim Thomas:      1.630
# 648. Damon Jones:      1.623
# 649. Hubert Davis:      1.616
# 650. Chris Ford:      1.616
# 651. Charles Oakley:      1.615
# 652. Chris Andersen:      1.614
# 653. Buck Johnson:      1.613
# 654. Kent Benson:      1.612
# 655. Terry Tyler:      1.610
# 656. Paul Arizin:      1.609
# 657. Ryan Gomes:      1.609
# 658. Michael Smith:      1.609
# 659. Maurice Harkless:      1.608
# 660. Terrence Ross:      1.607
# 661. Sam Bowie:      1.606
# 662. Bobby Jackson:      1.602
# 663. Drew Gooden:      1.600
# 664. Hakim Warrick:      1.599
# 665. Jim Chones:      1.598
# 666. DeMarre Carroll:      1.597
# 667. Bryant Stith:      1.597
# 668. Eric Snow:      1.596
# 669. Grant Long:      1.595
# 670. Ron Mercer:      1.593
# 671. Lance Stephenson:      1.593
# 672. Tyrone Corbin:      1.590
# 673. Randy Foye:      1.590
# 674. Raja Bell:      1.589
# 675. Matt Geiger:      1.586
# 676. Jodie Meeks:      1.586
# 677. Anthony Peeler:      1.586
# 678. Charlie Ward:      1.586
# 679. Tom Heinsohn:      1.584
# 680. Fred Roberts:      1.584
# 681. Darrell Walker:      1.584
# 682. Tyrone Hill:      1.583
# 683. Jason Thompson:      1.583
# 684. Marco Belinelli:      1.582
# 685. Marcus Smart:      1.582
# 686. Larry Smith:      1.582
# 687. Charlie Villanueva:      1.582
# 688. Chris Whitney:      1.582
# 689. Marcus Camby:      1.581
# 690. Morris Peterson:      1.581
# 691. P.J. Brown:      1.576
# 692. Steve Hawes:      1.575
# 693. Gus Johnson:      1.575
# 694. Kevin Grevey:      1.574
# 695. Joe Smith:      1.573
# 696. Brendan Haywood:      1.571
# 697. Desmond Mason:      1.570
# 698. Quinn Buckner:      1.569
# 699. Chris Childs:      1.568
# 700. Benoit Benjamin:      1.566
# 701. John Salmons:      1.566
# 702. Dave Robisch:      1.563
# 703. John Salley:      1.563
# 704. Dick Van Arsdale:      1.561
# 705. J.J. Hickson:      1.560
# 706. E'Twaun Moore:      1.560
# 707. Louis Orr:      1.560
# 708. Nate Williams:      1.560
# 709. Avery Bradley:      1.559
# 710. Foots Walker:      1.559
# 711. Mike Gale:      1.557
# 712. Bob Rule:      1.557
# 713. Flynn Robinson:      1.556
# 714. Patrick Patterson:      1.555
# 715. Dorell Wright:      1.554
# 716. Dave Corzine:      1.553
# 717. Kevin Duckworth:      1.550
# 718. Kosta Koufos:      1.549
# 719. Troy Hudson:      1.546
# 720. Evan Turner:      1.545
# 721. Todd Day:      1.542
# 722. Andray Blatche:      1.540
# 723. Alec Burks:      1.540
# 724. Mark West:      1.540
# 725. Chris Duhon:      1.539
# 726. Eric Piatkowski:      1.536
# 727. Dick Barnett:      1.535
# 728. M.L. Carr:      1.535
# 729. Fred Carter:      1.535
# 730. Earl Watson:      1.535
# 731. Channing Frye:      1.533
# 732. Ernie Grunfeld:      1.533
# 733. Pat Cummings:      1.532
# 734. Joe Caldwell:      1.531
# 735. Blair Rasmussen:      1.531
# 736. Jerryd Bayless:      1.529
# 737. Chris Kaman:      1.529
# 738. Billy Paultz:      1.528
# 739. Danny Green:      1.527
# 740. C.J. Watson:      1.527
# 741. Michael Kidd-Gilchrist:      1.526
# 742. Jerome Williams:      1.526
# 743. Jonas Jerebko:      1.523
# 744. Jim Price:      1.523
# 745. Walt Hazzard:      1.518
# 746. Ollie Johnson:      1.517
# 747. Bobby Simmons:      1.516
# 748. Calbert Cheaney:      1.514
# 749. Elden Campbell:      1.511
# 750. Jeff Foster:      1.508
# 751. Bill Robinzine:      1.508
# 752. Maurice Evans:      1.507
# 753. Aaron McKie:      1.506
# 754. Larry Steele:      1.505
# 755. Roy Hibbert:      1.502
# 756. Don Ohl:      1.502
# 757. Austin Rivers:      1.502
# 758. Herb Williams:      1.502
# 759. Steve Blake:      1.501
# 760. Omri Casspi:      1.501
# 761. Nick Young:      1.499
# 762. Udonis Haslem:      1.497
# 763. Spencer Hawes:      1.497
# 764. James Posey:      1.495
# 765. Lee Mayberry:      1.491
# 766. Kevin Edwards:      1.488
# 767. Clifford Ray:      1.483
# 768. Stacey Augmon:      1.482
# 769. Anthony Tolliver:      1.480
# 770. Andres Nocioni:      1.478
# 771. Guy Rodgers:      1.478
# 772. Olden Polynice:      1.477
# 773. Bill Russell:      1.477
# 774. Sam Mitchell:      1.476
# 775. Tom McMillen:      1.474
# 776. Samuel Dalembert:      1.473
# 777. Kurt Rambis:      1.473
# 778. Mike Sanders:      1.473
# 779. Rich Kelley:      1.469
# 780. Danny Schayes:      1.469
# 781. Sam Lacey:      1.468
# 782. Francisco Garcia:      1.467
# 783. Kurt Thomas:      1.467
# 784. Dave DeBusschere:      1.462
# 785. C.J. Miles:      1.462
# 786. Tracy Murray:      1.462
# 787. Bob Love:      1.461
# 788. Ben Poquette:      1.459
# 789. George McCloud:      1.458
# 790. Derek Fisher:      1.457
# 791. Kenny Thomas:      1.457
# 792. Howard Eisley:      1.456
# 793. Kevin Loughery:      1.455
# 794. Jack Marin:      1.455
# 795. Clem Haskins:      1.454
# 796. P.J. Tucker:      1.454
# 797. Henry Bibby:      1.452
# 798. Terry Dischinger:      1.451
# 799. Bryon Russell:      1.451
# 800. Ronald Murray:      1.450
# 801. Tony Allen:      1.447
# 802. Robert Horry:      1.446
# 803. Joe Meriweather:      1.443
# 804. Lamond Murray:      1.442
# 805. Rasho Nesterovic:      1.441
# 806. Malik Sealy:      1.441
# 807. Tony Snell:      1.441
# 808. Zelmo Beaty:      1.437
# 809. Clint Richardson:      1.436
# 810. Maurice Taylor:      1.432
# 811. Darius Miles:      1.431
# 812. Brian Shaw:      1.431
# 813. Zaza Pachulia:      1.430
# 814. Martell Webster:      1.428
# 815. Antonio Davis:      1.427
# 816. Gerald Green:      1.424
# 817. Bob Hansen:      1.424
# 818. Tony Delk:      1.423
# 819. Marquis Daniels:      1.420
# 820. Neil Johnston:      1.418
# 821. Jon McGlocklin:      1.418
# 822. Tree Rollins:      1.416
# 823. Adam Keefe:      1.413
# 824. Eduardo Najera:      1.412
# 825. Kevin Restani:      1.412
# 826. Ian Mahinmi:      1.411
# 827. Slick Watts:      1.411
# 828. Marreese Speights:      1.410
# 829. Chuck Hayes:      1.409
# 830. Quentin Richardson:      1.403
# 831. Corey Brewer:      1.402
# 832. Danny Ferry:      1.402
# 833. Fred Jones:      1.402
# 834. Erick Dampier:      1.399
# 835. Bill Hanzlik:      1.398
# 836. LaSalle Thompson:      1.398
# 837. Lucious Harris:      1.388
# 838. Keyon Dooling:      1.387
# 839. Kurt Nimphius:      1.386
# 840. Mickael Pietrus:      1.386
# 841. George Yardley:      1.382
# 842. Greg Buckner:      1.379
# 843. Happy Hairston:      1.378
# 844. Paul Griffin:      1.374
# 845. Thabo Sefolosha:      1.371
# 846. Clyde Lovellette:      1.365
# 847. Shandon Anderson:      1.364
# 848. Tom Van Arsdale:      1.364
# 849. Sebastian Telfair:      1.362
# 850. Mark Blount:      1.358
# 851. Anthony Johnson:      1.357
# 852. Bill Bradley:      1.355
# 853. Othella Harrington:      1.355
# 854. Ben McLemore:      1.355
# 855. Jerome Whitehead:      1.355
# 856. Wayne Ellington:      1.354
# 857. Bismack Biyombo:      1.350
# 858. Bob Boozer:      1.348
# 859. Curtis Rowe:      1.345
# 860. Kelvin Cato:      1.341
# 861. Popeye Jones:      1.341
# 862. Alan Henderson:      1.339
# 863. Theo Ratliff:      1.338
# 864. Neal Walk:      1.338
# 865. Carlos Delfino:      1.336
# 866. Bill Sharman:      1.334
# 867. Red Kerr:      1.333
# 868. Chucky Brown:      1.331
# 869. Herm Gilliam:      1.331
# 870. Aaron Williams:      1.328
# 871. Rudy LaRusso:      1.325
# 872. Bob Kauffman:      1.322
# 873. Vladimir Radmanovic:      1.321
# 874. Dante Cunningham:      1.319
# 875. Dwight Jones:      1.317
# 876. Mike Bratz:      1.315
# 877. J.R. Reid:      1.314
# 878. Alton Lister:      1.310
# 879. Leon Douglas:      1.309
# 880. Lindsey Hunter:      1.309
# 881. Bob Wilkerson:      1.309
# 882. Tony Battie:      1.308
# 883. Mark Bryant:      1.306
# 884. Eddie Miles:      1.302
# 885. Rick Mahorn:      1.298
# 886. Larry Costello:      1.296
# 887. Nate Thurmond:      1.296
# 888. Joe Bryant:      1.294
# 889. Kris Humphries:      1.294
# 890. Kevin Kunnert:      1.294
# 891. James Bailey:      1.292
# 892. Will Perdue:      1.287
# 893. T.R. Dunn:      1.286
# 894. Willie Green:      1.285
# 895. Eddie House:      1.285
# 896. Curtis Perry:      1.285
# 897. Marvin Webster:      1.284
# 898. Wally Walker:      1.282
# 899. Eric Williams:      1.280
# 900. Willie Naulls:      1.276
# 901. Joel Przybilla:      1.274
# 902. Clemon Johnson:      1.272
# 903. Ed Macauley:      1.271
# 904. Jerry Sloan:      1.271
# 905. Stromile Swift:      1.270
# 906. Al-Farouq Aminu:      1.269
# 907. Kent Bazemore:      1.269
# 908. John Brown:      1.269
# 909. Wayne Cooper:      1.268
# 910. Jim Barnett:      1.267
# 911. Travis Outlaw:      1.266
# 912. Erick Strickland:      1.266
# 913. John Gianelli:      1.265
# 914. Ben Wallace:      1.264
# 915. Johnny Green:      1.258
# 916. Brad Lohaus:      1.254
# 917. Ray Scott:      1.254
# 918. Armond Hill:      1.253
# 919. Kwame Brown:      1.245
# 920. George Lynch:      1.245
# 921. Austin Croshere:      1.243
# 922. Alvin Scott:      1.242
# 923. Randy Breuer:      1.241
# 924. Tom Gola:      1.237
# 925. Jacque Vaughn:      1.235
# 926. Shawn Bradley:      1.230
# 927. Lorenzen Wright:      1.226
# 928. Kendrick Perkins:      1.223
# 929. Anthony Carter:      1.222
# 930. Jason Maxiell:      1.220
# 931. Danny Vranes:      1.215
# 932. Stu Lantz:      1.213
# 933. Pat Garrity:      1.212
# 934. Greg Anderson:      1.211
# 935. Jason Smith:      1.210
# 936. Paul Neumann:      1.205
# 937. Damien Wilkins:      1.204
# 938. Ron Williams:      1.204
# 939. Luc Mbah a Moute:      1.200
# 940. Kevin Ollie:      1.197
# 941. Mike Riordan:      1.196
# 942. Paul Silas:      1.196
# 943. Scott Williams:      1.195
# 944. Garrett Temple:      1.191
# 945. Al Attles:      1.184
# 946. Tom Boerwinkle:      1.184
# 947. Corky Calhoun:      1.184
# 948. Rod Thorn:      1.184
# 949. Ervin Johnson:      1.180
# 950. Terry Davis:      1.179
# 951. Tom Hammonds:      1.179
# 952. David Wingate:      1.177
# 953. Glen Davis:      1.176
# 954. Phil Jackson:      1.176
# 955. Andrew Lang:      1.176
# 956. Luc Longley:      1.174
# 957. Jamaal Magloire:      1.167
# 958. Keith Bogans:      1.162
# 959. Tom Meschery:      1.161
# 960. Nazr Mohammed:      1.161
# 961. DeShawn Stevenson:      1.161
# 962. Trenton Hassell:      1.159
# 963. James Jones:      1.159
# 964. Iman Shumpert:      1.157
# 965. Sidney Green:      1.154
# 966. Don Kojis:      1.153
# 967. Bill Bridges:      1.152
# 968. Dolph Schayes:      1.150
# 969. Michael Curry:      1.144
# 970. Dudley Bradley:      1.143
# 971. Jeff Turner:      1.143
# 972. Greg Ostertag:      1.133
# 973. Sean Rooks:      1.133
# 974. Felton Spencer:      1.133
# 975. Rasual Butler:      1.130
# 976. Jon Koncak:      1.130
# 977. Vitaly Potapenko:      1.130
# 978. Don Nelson:      1.128
# 979. Larry Siegfried:      1.127
# 980. Jeff Wilkins:      1.125
# 981. Adrian Smith:      1.122
# 982. Brandon Rush:      1.114
# 983. Wayne Embry:      1.111
# 984. Caldwell Jones:      1.111
# 985. Bucky Bockhorn:      1.109
# 986. Kenny Sears:      1.099
# 987. Tony Massenburg:      1.091
# 988. Wali Jones:      1.086
# 989. Wesley Johnson:      1.085
# 990. Earl Cureton:      1.064
# 991. Keith Erickson:      1.064
# 992. Howard Komives:      1.064
# 993. Brian Skinner:      1.056
# 994. Bob Weiss:      1.056
# 995. Jim Fox:      1.055
# 996. John Block:      1.047
# 997. Charles Jones:      1.036
# 998. Gar Heard:      1.033
# 999. Joe Kleine:      1.030
# 1000. Jim Brewer:      1.017
# 1001. Don Chaney:      1.011
# 1002. Jim Washington:      1.011
# 1003. Malik Rose:      1.010
# 1004. Zaid Abdul-Aziz:      1.005
# 1005. Jan van Breda Kolff:      1.004
# 1006. Randy Brown:      1.003
# 1007. Matt Guokas:      1.003
# 1008. Greg Smith:      1.000
# 1009. Vern Mikkelsen:      0.998
# 1010. Gene Shue:      0.995
# 1011. Bruce Bowen:      0.989
# 1012. Mike Brown:      0.988
# 1013. Johnny Egan:      0.987
# 1014. John Barnhill:      0.985
# 1015. Rick Adelman:      0.978
# 1016. Dave Stallworth:      0.976
# 1017. Jared Jeffries:      0.973
# 1018. Connie Dierking:      0.965
# 1019. Reggie Evans:      0.956
# 1020. Leroy Ellis:      0.955
# 1021. Walter McCarty:      0.949
# 1022. Larry Foust:      0.943
# 1023. John Tresvant:      0.943
# 1024. Devean George:      0.937
# 1025. Dick Garmaker:      0.931
# 1026. Mark Eaton:      0.930
# 1027. Len Chappell:      0.928
# 1028. Si Green:      0.923
# 1029. Dave Gambee:      0.920
# 1030. Frank Ramsey:      0.914
# 1031. Mel Counts:      0.913
# 1032. Bob Ferry:      0.910
# 1033. Adonal Foyle:      0.910
# 1034. Otto Moore:      0.906
# 1035. Dennis Awtrey:      0.901
# 1036. Carl Braun:      0.897
# 1037. Rick Roberson:      0.891
# 1038. K.C. Jones:      0.887
# 1039. Em Bryant:      0.885
# 1040. Jim King:      0.881
# 1041. Darrall Imhoff:      0.879
# 1042. Tom Hawkins:      0.873
# 1043. Luke Jackson:      0.870
# 1044. Tom Sanders:      0.867
# 1045. Barry Clemens:      0.847
# 1046. Harry Gallatin:      0.842
# 1047. Jack Coleman:      0.836
# 1048. Jim Davis:      0.821
# 1049. Joe Ellis:      0.819
# 1050. Michael Olowokandi:      0.813
# 1051. Don Adams:      0.802
# 1052. Walt Wesley:      0.797
# 1053. Phil Jordon:      0.793
# 1054. Bobby Wanzer:      0.789
# 1055. Al Bianchi:      0.785
# 1056. Ray Felix:      0.781
# 1057. Mel Hutchins:      0.774
# 1058. Arnie Risen:      0.755
# 1059. McCoy McLemore:      0.749
# 1060. George Johnson:      0.743
# 1061. Frank Selvy:      0.733
# 1062. Cornell Warner:      0.727
# 1063. Clyde Lee:      0.720
# 1064. Woody Sauldsberry:      0.702
# 1065. Red Rocha:      0.664
# 1066. George King:      0.661
# 1067. Jack Nichols:      0.649
# 1068. Chris Dudley:      0.648
# 1069. Jason Collins:      0.647
# 1070. Harvey Catchings:      0.638
# 1071. Joe Graboski:      0.632
# 1072. Ed Conlin:      0.626
# 1073. Toby Kimball:      0.626
# 1074. Jack George:      0.612
# 1075. Jim Krebs:      0.610
# 1076. Walter Dukes:      0.607
# 1077. Nat Clifton:      0.596
# 1078. Slater Martin:      0.570
# 1079. Slick Leonard:      0.547
# 1080. Chuck Share:      0.543
# 1081. Andy Phillip:      0.539
# 1082. Dick McGuire:      0.517
# 1083. Greg Kite:      0.500
# 1084. Paul Seymour:      0.496
# 1085. Earl Lloyd:      0.469
# 1086. Jack McMahon:      0.392
# 1087. Bob Harrison:      0.386
# 1088. Manute Bol:      0.306
